# %% [markdown]
# # Importing csv files to shadow
# awojdyla@lbl.gov, Feb 2026
#
# It is recommended to use the Python widget inside Oasys to make it happen

# %%
import Shadow
#Shadow.ShadowTools.write_shadow_surface(H, x_m, y_m, outFile = './mirror_file.dat'.)

# %%
filepath = "/Users/awojdyla/Downloads/ssrl_bl10-1_M0_mirror_Ux_Data_02-25-26.csv"

x_m = pd.to_numeric(df.index, errors="coerce").to_numpy()
y_m = pd.to_numeric(df.columns, errors="coerce").to_numpy()
H = df.apply(pd.to_numeric, errors="coerce").to_numpy()
